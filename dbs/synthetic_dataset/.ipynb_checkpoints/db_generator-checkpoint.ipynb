# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random
from pprint import pprint
import copy


# Load the provided files
stock_file_path = './initial_stock.csv'
classified_products_file_path = './products.csv'

stock_df = pd.read_csv(stock_file_path)
classified_products_df = pd.read_csv(classified_products_file_path)

# Display the structure of the files to ensure we understand their contents
stock_df.head(), classified_products_df.head()
# Out:
# (   product_id  quantity expiry_date  shelf_life  time_in_stock
#  0           1        21  2025-02-28          47             13
#  1           2        15  2025-05-13         121             20
#  2           3        25  2025-05-02         110              8
#  3           4        26  2025-06-17         156              0
#  4           5        23  2025-08-29         229             16,
#           Product_Name        Brand    Category Usage_Frequency  Price_USD  \
#  0      Magic Eyeliner     Shiseido    CC Cream          Weekly     149.16
#  1   Perfect Lip Liner  Huda Beauty   Lip Gloss          Weekly      62.28
#  2  Divine Highlighter     Bourjois     Mascara      Occasional      51.65
#  3   Ultra Highlighter     Shiseido      Primer           Daily      71.25
#  4     Ultra Lip Gloss      Kiehl’s  Eye Shadow          Weekly      78.36
#
#     Rating  Number_of_Reviews Product_Size  Skin_Type Gender_Target  \
#  0     4.4               6158         50ml  Sensitive        Female
#  1     3.7               7809        150ml        Dry          Male
#  2     2.1               3815        250ml        Dry        Female
#  3     4.0               5749        150ml       Oily        Female
#  4     1.9               3534         30ml     Normal          Male
#
#    Packaging_Type Main_Ingredient  Cruelty_Free Country_of_Origin Product Name  \
#  0            Jar     Shea Butter          True               USA   Product 21
#  1            Jar        Glycerin         False                UK   Product 22
#  2         Bottle     Shea Butter          True         Australia   Product 23
#  3         Bottle     Shea Butter         False            France   Product 24
#  4           Tube       Aloe Vera         False               USA   Product 25
#
#    Rotation  id
#  0     High   1
#  1     High   2
#  2     High   3
#  3     High   4
#  4     High   5  )

# %%
# Initialize parameters and data structures
start_date = datetime(2020, 1, 1)
end_date = datetime(2024, 12, 31)
current_date = start_date
warehouse_capacity = 500 # capacidad total del almacén

# Merge stock with product details for easier reference
products = pd.merge(stock_df, classified_products_df, left_on='product_id', right_on='id')

# Create the updated stock dictionary to handle multiple batches per product
initial_stock = {}

for _, row in stock_df.iterrows():
    product_id = row['product_id']
    batch = {
        'quantity': row['quantity'],
        'expiry_date': datetime.strptime(row['expiry_date'], '%Y-%m-%d')
    }
    if product_id not in initial_stock:
        initial_stock[product_id] = []
    initial_stock[product_id].append(batch)

stock = copy.deepcopy(initial_stock)

# Display the updated stock dictionary
#pprint(stock)


sales_data = []  # To store sales records
unsold_products = {}  # To store unsold products and their details

# Helper function for restocking
def restock(stock, initial_stock, current_date):

    print('RESTORIIIIINGGG!!!')

    for product_id, batches in stock.items():
        # Calcular la cantidad inicial requerida sumando los lotes
        initial_quantity = sum(batch['quantity'] for batch in initial_stock.get(product_id, []))
        
        # Calcular la cantidad actual disponible sumando los lotes existentes
        current_quantity = sum(batch['quantity'] for batch in batches)
        
        # Determinar la cantidad faltante para llegar al stock inicial
        missing_quantity = initial_quantity - current_quantity
        
        if missing_quantity > 0:
            # Crear un nuevo batch para reponer el stock faltante
            new_batch = {
                'quantity': missing_quantity,
                'expiry_date': current_date + timedelta(days=random.randint(180, 240))
            }
            # Agregar el nuevo batch al stock del producto
            stock[product_id].append(new_batch)


# Factores de ajuste
def get_adjustment_factor(current_date):

    # Ajustes por día del mes (principios de mes)
    if current_date.day <= 7:
        day_factor = 1.3
    else:
        day_factor = 1

    # Ajustes por día de la semana (fines de semana)
    if current_date.weekday() in [5, 6]:  # Sábado y domingo
        weekend_factor = 3.0
    else:
        weekend_factor = 1

    # Factor final
    return day_factor * weekend_factor

monthly_demand_factor = {
    1: 1.5,  # Enero
    7: 1.3,  # Julio
    8: 1.3,  # Agosto
    12: 1.5, # Diciembre
    2: 1,
    3: 1,
    4: 1,
    5: 1,
    6: 1,
    9: 1,
    10: 1,
    11: 1
}

# Simulate daily sales
while current_date <= end_date:
    month = current_date.month
    
    # Base sales adjusted by month and day factors
    base_sales = random.randint(4,8)
    adjustment_factor = get_adjustment_factor(current_date)
    daily_sales_count = int(base_sales * adjustment_factor) * monthly_demand_factor[month]
    
    daily_sales = []
    total_items_sold = 0

    # Al inicio del día:
    # Verificar productos caducados
    for product_id, batches in stock.items():
        expired_batches = [batch for batch in batches if batch['expiry_date'] <= current_date]
        if expired_batches:
            # Registrar los lotes caducados en `unsold_products`
            if product_id not in unsold_products:
                unsold_products[product_id] = []
            unsold_products[product_id].extend(expired_batches)
            
            # Eliminar los lotes caducados del stock
            stock[product_id] = [batch for batch in batches if batch['expiry_date'] > current_date]

    # Reabastecer si es el primer lunes del mes
    if current_date.weekday() == 0 and (1 <= current_date.day <= 7 or 15 <= current_date.day <= 21):
        restock(stock, initial_stock, current_date)

    
    
    while total_items_sold < daily_sales_count:
        
        # Extract available products [6,8,28,23,1,14,...]
        available_products = [p for p in stock if any(batch['quantity'] > 0 for batch in stock[p])]
        """ print('Available products: ', available_products) """

    
        # Si no hay productos en el almacén
        if not available_products:
            raise ValueError("ALMACÉN VACÍO!!!!!")
            break
        

        # Clasificar productos según la rotación
        high_rotation = [p for p in available_products if products[products['product_id'] == p].iloc[0]['Rotation'] == 'High']
        medium_rotation = [p for p in available_products if products[products['product_id'] == p].iloc[0]['Rotation'] == 'Medium']

        # 1. Seleccionar 5 productos de media rotación
        medium_pool = random.sample(medium_rotation, min(5, len(medium_rotation)))

        # 2. Modificar el pool de alta rotación
        high_pool = high_rotation.copy()
        
        # 3. Sumar los pools de alta y media rotación. De la suma total quito 2 y sumo entre 0 y 2.
        final_pool = medium_pool + high_pool

        if len(final_pool) > 2:
            final_pool = random.sample(final_pool, len(final_pool) - 2)  # Quitar 2 productos aleatorios
            duplicates = random.choices(final_pool, k=random.randint(0, 2)) # Seleccionar 2 productos para duplicar
            final_pool.extend(duplicates)  # Duplicar productos seleccionados

        # 3. Combinar ambos pools y mezclarlos
        final_pool = medium_pool + high_pool
        random.shuffle(final_pool)  # Mezclar los productos

        # 4. Procesar ventas en el orden del pool mezclado
        for product_id in final_pool:
            if total_items_sold >= daily_sales_count:
                break

            # Obtener detalles del producto
            product_details = products[products['product_id'] == product_id].iloc[0]

            # Determinar la cantidad a vender (1 o 2 unidades con proporción 90-10)
            sold_quantity = 1 if random.random() < 0.9 else 2

            # Verificar el stock disponible
            batches = sorted(stock[product_id], key=lambda batch: batch['expiry_date'])
            total_stock = sum(b['quantity'] for b in batches)
            sold_quantity = min(sold_quantity, total_stock)

            # Procesar ventas desde los lotes
            remaining_quantity = sold_quantity
            for batch in batches:
                if remaining_quantity <= 0:
                    break
                quantity_to_sell = min(batch['quantity'], remaining_quantity)
                batch['quantity'] -= quantity_to_sell
                remaining_quantity -= quantity_to_sell

            # Registrar la venta
            total_items_in_stock = sum(
                batch['quantity'] for product_batches in stock.values() for batch in product_batches
            )
            sales_data.append({
                'sale_id': len(sales_data) + 1,
                'product_id': product_id,
                'date': current_date,
                'quantity': sold_quantity,
                'total_price': sold_quantity * product_details['Price_USD'],
                'batch_expiry_date': batches[0]['expiry_date'],  # Lote más cercano a caducar
                'remaining_stock': total_stock - sold_quantity,
                'warehouse_occupancy_rate': total_items_in_stock / warehouse_capacity * 100
            })

            total_items_sold += sold_quantity

            # Eliminar lotes vacíos
            batches = [batch for batch in batches if batch['quantity'] > 0]
            stock[product_id] = batches

            # Calcular el total de ítems en el almacén
            print(f"Total de ítems en el almacén: {total_items_in_stock}")


        
    print(f"\nCurrent_date: {current_date}\n")
    #pprint(sales_data)
    # Move to the next day
    current_date += timedelta(days=1)

# Convert sales data to a DataFrame and save
sales_df = pd.DataFrame(sales_data)
sales_file_path = './sales_test.csv'
sales_df.to_csv(sales_file_path, index=False)
# Out:
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 423
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 417
# Total de ítems en el almacén: 416
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
#
# Current_date: 2020-01-01 00:00:00
#
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
# Total de ítems en el almacén: 409
# Total de ítems en el almacén: 408
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 405
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
#
# Current_date: 2020-01-02 00:00:00
#
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 398
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
# Total de ítems en el almacén: 394
# Total de ítems en el almacén: 392
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 388
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 385
#
# Current_date: 2020-01-03 00:00:00
#
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 381
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 376
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
# Total de ítems en el almacén: 373
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
#
# Current_date: 2020-01-04 00:00:00
#
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 353
# Total de ítems en el almacén: 352
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 350
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 338
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 334
# Total de ítems en el almacén: 333
#
# Current_date: 2020-01-05 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 423
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 421
# Total de ítems en el almacén: 420
#
# Current_date: 2020-01-06 00:00:00
#
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 417
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
# Total de ítems en el almacén: 409
# Total de ítems en el almacén: 408
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 406
#
# Current_date: 2020-01-07 00:00:00
#
# Total de ítems en el almacén: 405
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 398
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
# Total de ítems en el almacén: 394
#
# Current_date: 2020-01-08 00:00:00
#
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 392
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 385
#
# Current_date: 2020-01-09 00:00:00
#
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 376
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
#
# Current_date: 2020-01-10 00:00:00
#
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 353
# Total de ítems en el almacén: 352
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 350
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
# Total de ítems en el almacén: 344
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 338
#
# Current_date: 2020-01-11 00:00:00
#
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 334
# Total de ítems en el almacén: 333
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
# Total de ítems en el almacén: 330
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
# Total de ítems en el almacén: 326
# Total de ítems en el almacén: 325
# Total de ítems en el almacén: 324
# Total de ítems en el almacén: 323
# Total de ítems en el almacén: 321
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 313
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
# Total de ítems en el almacén: 306
#
# Current_date: 2020-01-12 00:00:00
#
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 302
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 299
# Total de ítems en el almacén: 298
# Total de ítems en el almacén: 297
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 294
#
# Current_date: 2020-01-13 00:00:00
#
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 291
# Total de ítems en el almacén: 290
# Total de ítems en el almacén: 289
# Total de ítems en el almacén: 288
#
# Current_date: 2020-01-14 00:00:00
#
# Total de ítems en el almacén: 287
# Total de ítems en el almacén: 286
# Total de ítems en el almacén: 285
# Total de ítems en el almacén: 284
# Total de ítems en el almacén: 283
# Total de ítems en el almacén: 282
# Total de ítems en el almacén: 281
# Total de ítems en el almacén: 280
# Total de ítems en el almacén: 279
# Total de ítems en el almacén: 278
# Total de ítems en el almacén: 276
#
# Current_date: 2020-01-15 00:00:00
#
# Total de ítems en el almacén: 275
# Total de ítems en el almacén: 274
# Total de ítems en el almacén: 273
# Total de ítems en el almacén: 272
# Total de ítems en el almacén: 271
# Total de ítems en el almacén: 270
#
# Current_date: 2020-01-16 00:00:00
#
# Total de ítems en el almacén: 268
# Total de ítems en el almacén: 267
# Total de ítems en el almacén: 266
# Total de ítems en el almacén: 265
# Total de ítems en el almacén: 264
# Total de ítems en el almacén: 263
# Total de ítems en el almacén: 261
#
# Current_date: 2020-01-17 00:00:00
#
# Total de ítems en el almacén: 260
# Total de ítems en el almacén: 259
# Total de ítems en el almacén: 258
# Total de ítems en el almacén: 257
# Total de ítems en el almacén: 256
# Total de ítems en el almacén: 255
# Total de ítems en el almacén: 254
# Total de ítems en el almacén: 253
# Total de ítems en el almacén: 252
# Total de ítems en el almacén: 251
# Total de ítems en el almacén: 250
# Total de ítems en el almacén: 249
# Total de ítems en el almacén: 248
# Total de ítems en el almacén: 247
# Total de ítems en el almacén: 246
# Total de ítems en el almacén: 245
# Total de ítems en el almacén: 244
# Total de ítems en el almacén: 243
# Total de ítems en el almacén: 242
# Total de ítems en el almacén: 241
# Total de ítems en el almacén: 239
# Total de ítems en el almacén: 238
#
# Current_date: 2020-01-18 00:00:00
#
# Total de ítems en el almacén: 237
# Total de ítems en el almacén: 236
# Total de ítems en el almacén: 235
# Total de ítems en el almacén: 234
# Total de ítems en el almacén: 233
# Total de ítems en el almacén: 232
# Total de ítems en el almacén: 231
# Total de ítems en el almacén: 230
# Total de ítems en el almacén: 229
# Total de ítems en el almacén: 228
# Total de ítems en el almacén: 227
# Total de ítems en el almacén: 226
# Total de ítems en el almacén: 225
# Total de ítems en el almacén: 224
# Total de ítems en el almacén: 223
# Total de ítems en el almacén: 222
# Total de ítems en el almacén: 221
# Total de ítems en el almacén: 220
#
# Current_date: 2020-01-19 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 421
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 417
#
# Current_date: 2020-01-20 00:00:00
#
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
# Total de ítems en el almacén: 409
# Total de ítems en el almacén: 408
#
# Current_date: 2020-01-21 00:00:00
#
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
#
# Current_date: 2020-01-22 00:00:00
#
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 398
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
# Total de ítems en el almacén: 394
#
# Current_date: 2020-01-23 00:00:00
#
# Total de ítems en el almacén: 392
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 388
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 385
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
#
# Current_date: 2020-01-24 00:00:00
#
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 381
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 376
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
# Total de ítems en el almacén: 373
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 353
# Total de ítems en el almacén: 351
#
# Current_date: 2020-01-25 00:00:00
#
# Total de ítems en el almacén: 350
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 338
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 334
# Total de ítems en el almacén: 333
#
# Current_date: 2020-01-26 00:00:00
#
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
# Total de ítems en el almacén: 330
# Total de ítems en el almacén: 329
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
# Total de ítems en el almacén: 326
# Total de ítems en el almacén: 325
# Total de ítems en el almacén: 324
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 321
#
# Current_date: 2020-01-27 00:00:00
#
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 317
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 313
# Total de ítems en el almacén: 312
#
# Current_date: 2020-01-28 00:00:00
#
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 303
#
# Current_date: 2020-01-29 00:00:00
#
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 298
# Total de ítems en el almacén: 297
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 294
#
# Current_date: 2020-01-30 00:00:00
#
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 291
# Total de ítems en el almacén: 290
# Total de ítems en el almacén: 289
# Total de ítems en el almacén: 288
# Total de ítems en el almacén: 287
# Total de ítems en el almacén: 286
#
# Current_date: 2020-01-31 00:00:00
#
# Total de ítems en el almacén: 285
# Total de ítems en el almacén: 284
# Total de ítems en el almacén: 283
# Total de ítems en el almacén: 282
# Total de ítems en el almacén: 281
# Total de ítems en el almacén: 280
# Total de ítems en el almacén: 279
# Total de ítems en el almacén: 278
# Total de ítems en el almacén: 277
# Total de ítems en el almacén: 276
# Total de ítems en el almacén: 275
# Total de ítems en el almacén: 274
# Total de ítems en el almacén: 273
# Total de ítems en el almacén: 272
# Total de ítems en el almacén: 271
#
# Current_date: 2020-02-01 00:00:00
#
# Total de ítems en el almacén: 270
# Total de ítems en el almacén: 269
# Total de ítems en el almacén: 267
# Total de ítems en el almacén: 266
# Total de ítems en el almacén: 265
# Total de ítems en el almacén: 263
# Total de ítems en el almacén: 262
# Total de ítems en el almacén: 261
# Total de ítems en el almacén: 260
# Total de ítems en el almacén: 259
# Total de ítems en el almacén: 258
# Total de ítems en el almacén: 257
# Total de ítems en el almacén: 256
# Total de ítems en el almacén: 255
# Total de ítems en el almacén: 254
# Total de ítems en el almacén: 253
# Total de ítems en el almacén: 252
# Total de ítems en el almacén: 251
# Total de ítems en el almacén: 250
# Total de ítems en el almacén: 249
# Total de ítems en el almacén: 248
# Total de ítems en el almacén: 247
# Total de ítems en el almacén: 246
# Total de ítems en el almacén: 245
# Total de ítems en el almacén: 244
#
# Current_date: 2020-02-02 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 423
# Total de ítems en el almacén: 421
#
# Current_date: 2020-02-03 00:00:00
#
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 417
# Total de ítems en el almacén: 415
#
# Current_date: 2020-02-04 00:00:00
#
# Total de ítems en el almacén: 414
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
# Total de ítems en el almacén: 409
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 405
#
# Current_date: 2020-02-05 00:00:00
#
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 398
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
#
# Current_date: 2020-02-06 00:00:00
#
# Total de ítems en el almacén: 394
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 392
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 388
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
#
# Current_date: 2020-02-07 00:00:00
#
# Total de ítems en el almacén: 385
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 381
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 376
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
#
# Current_date: 2020-02-08 00:00:00
#
# Total de ítems en el almacén: 373
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 352
#
# Current_date: 2020-02-09 00:00:00
#
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 350
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
#
# Current_date: 2020-02-10 00:00:00
#
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 337
#
# Current_date: 2020-02-11 00:00:00
#
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 334
# Total de ítems en el almacén: 332
#
# Current_date: 2020-02-12 00:00:00
#
# Total de ítems en el almacén: 331
# Total de ítems en el almacén: 330
# Total de ítems en el almacén: 329
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
#
# Current_date: 2020-02-13 00:00:00
#
# Total de ítems en el almacén: 326
# Total de ítems en el almacén: 325
# Total de ítems en el almacén: 324
# Total de ítems en el almacén: 323
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 321
#
# Current_date: 2020-02-14 00:00:00
#
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 317
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 313
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 302
#
# Current_date: 2020-02-15 00:00:00
#
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 299
# Total de ítems en el almacén: 298
# Total de ítems en el almacén: 297
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 294
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 291
# Total de ítems en el almacén: 290
#
# Current_date: 2020-02-16 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 423
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 421
#
# Current_date: 2020-02-17 00:00:00
#
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 417
# Total de ítems en el almacén: 416
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
# Total de ítems en el almacén: 413
#
# Current_date: 2020-02-18 00:00:00
#
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
# Total de ítems en el almacén: 408
#
# Current_date: 2020-02-19 00:00:00
#
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 405
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
#
# Current_date: 2020-02-20 00:00:00
#
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 398
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
# Total de ítems en el almacén: 394
#
# Current_date: 2020-02-21 00:00:00
#
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 388
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 385
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 376
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
# Total de ítems en el almacén: 372
#
# Current_date: 2020-02-22 00:00:00
#
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
#
# Current_date: 2020-02-23 00:00:00
#
# Total de ítems en el almacén: 353
# Total de ítems en el almacén: 352
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 350
#
# Current_date: 2020-02-24 00:00:00
#
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
#
# Current_date: 2020-02-25 00:00:00
#
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
#
# Current_date: 2020-02-26 00:00:00
#
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 338
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
#
# Current_date: 2020-02-27 00:00:00
#
# Total de ítems en el almacén: 334
# Total de ítems en el almacén: 333
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
#
# Current_date: 2020-02-28 00:00:00
#
# Total de ítems en el almacén: 330
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
# Total de ítems en el almacén: 326
# Total de ítems en el almacén: 325
# Total de ítems en el almacén: 324
# Total de ítems en el almacén: 323
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 317
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 313
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
#
# Current_date: 2020-02-29 00:00:00
#
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 303
# Total de ítems en el almacén: 302
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 299
# Total de ítems en el almacén: 298
# Total de ítems en el almacén: 297
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 291
# Total de ítems en el almacén: 290
# Total de ítems en el almacén: 289
# Total de ítems en el almacén: 287
# Total de ítems en el almacén: 286
# Total de ítems en el almacén: 285
# Total de ítems en el almacén: 284
# Total de ítems en el almacén: 283
#
# Current_date: 2020-03-01 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 423
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 421
#
# Current_date: 2020-03-02 00:00:00
#
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 416
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
#
# Current_date: 2020-03-03 00:00:00
#
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
# Total de ítems en el almacén: 409
#
# Current_date: 2020-03-04 00:00:00
#
# Total de ítems en el almacén: 408
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 405
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
# Total de ítems en el almacén: 399
#
# Current_date: 2020-03-05 00:00:00
#
# Total de ítems en el almacén: 398
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
# Total de ítems en el almacén: 394
#
# Current_date: 2020-03-06 00:00:00
#
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 388
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 385
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 381
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
# Total de ítems en el almacén: 373
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
#
# Current_date: 2020-03-07 00:00:00
#
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 352
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 350
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
#
# Current_date: 2020-03-08 00:00:00
#
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
#
# Current_date: 2020-03-09 00:00:00
#
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
#
# Current_date: 2020-03-10 00:00:00
#
# Total de ítems en el almacén: 338
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 333
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
#
# Current_date: 2020-03-11 00:00:00
#
# Total de ítems en el almacén: 330
# Total de ítems en el almacén: 329
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
# Total de ítems en el almacén: 326
# Total de ítems en el almacén: 325
#
# Current_date: 2020-03-12 00:00:00
#
# Total de ítems en el almacén: 324
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 321
#
# Current_date: 2020-03-13 00:00:00
#
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 313
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 307
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 303
# Total de ítems en el almacén: 302
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 299
# Total de ítems en el almacén: 297
#
# Current_date: 2020-03-14 00:00:00
#
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 294
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 291
# Total de ítems en el almacén: 290
# Total de ítems en el almacén: 289
# Total de ítems en el almacén: 288
# Total de ítems en el almacén: 287
# Total de ítems en el almacén: 286
# Total de ítems en el almacén: 285
# Total de ítems en el almacén: 284
# Total de ítems en el almacén: 283
# Total de ítems en el almacén: 282
#
# Current_date: 2020-03-15 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 423
# Total de ítems en el almacén: 422
#
# Current_date: 2020-03-16 00:00:00
#
# Total de ítems en el almacén: 421
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
#
# Current_date: 2020-03-17 00:00:00
#
# Total de ítems en el almacén: 417
# Total de ítems en el almacén: 416
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
#
# Current_date: 2020-03-18 00:00:00
#
# Total de ítems en el almacén: 408
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 405
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
#
# Current_date: 2020-03-19 00:00:00
#
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 398
#
# Current_date: 2020-03-20 00:00:00
#
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
# Total de ítems en el almacén: 394
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 385
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
#
# Current_date: 2020-03-21 00:00:00
#
# Total de ítems en el almacén: 376
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
# Total de ítems en el almacén: 373
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 352
#
# Current_date: 2020-03-22 00:00:00
#
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 350
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
#
# Current_date: 2020-03-23 00:00:00
#
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
#
# Current_date: 2020-03-24 00:00:00
#
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 338
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
#
# Current_date: 2020-03-25 00:00:00
#
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 333
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
# Total de ítems en el almacén: 330
#
# Current_date: 2020-03-26 00:00:00
#
# Total de ítems en el almacén: 329
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
# Total de ítems en el almacén: 326
# Total de ítems en el almacén: 325
#
# Current_date: 2020-03-27 00:00:00
#
# Total de ítems en el almacén: 324
# Total de ítems en el almacén: 323
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 321
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 317
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 313
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 303
# Total de ítems en el almacén: 301
#
# Current_date: 2020-03-28 00:00:00
#
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 299
# Total de ítems en el almacén: 298
# Total de ítems en el almacén: 297
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 294
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 291
# Total de ítems en el almacén: 290
# Total de ítems en el almacén: 289
# Total de ítems en el almacén: 288
# Total de ítems en el almacén: 287
# Total de ítems en el almacén: 286
# Total de ítems en el almacén: 285
# Total de ítems en el almacén: 284
# Total de ítems en el almacén: 283
# Total de ítems en el almacén: 282
# Total de ítems en el almacén: 281
# Total de ítems en el almacén: 280
# Total de ítems en el almacén: 279
# Total de ítems en el almacén: 277
#
# Current_date: 2020-03-29 00:00:00
#
# Total de ítems en el almacén: 276
# Total de ítems en el almacén: 274
# Total de ítems en el almacén: 273
# Total de ítems en el almacén: 272
# Total de ítems en el almacén: 271
# Total de ítems en el almacén: 270
#
# Current_date: 2020-03-30 00:00:00
#
# Total de ítems en el almacén: 269
# Total de ítems en el almacén: 268
# Total de ítems en el almacén: 267
# Total de ítems en el almacén: 266
#
# Current_date: 2020-03-31 00:00:00
#
# Total de ítems en el almacén: 265
# Total de ítems en el almacén: 263
# Total de ítems en el almacén: 262
# Total de ítems en el almacén: 261
# Total de ítems en el almacén: 260
# Total de ítems en el almacén: 259
# Total de ítems en el almacén: 258
# Total de ítems en el almacén: 257
# Total de ítems en el almacén: 256
#
# Current_date: 2020-04-01 00:00:00
#
# Total de ítems en el almacén: 255
# Total de ítems en el almacén: 254
# Total de ítems en el almacén: 253
# Total de ítems en el almacén: 252
# Total de ítems en el almacén: 251
#
# Current_date: 2020-04-02 00:00:00
#
# Total de ítems en el almacén: 250
# Total de ítems en el almacén: 249
# Total de ítems en el almacén: 248
# Total de ítems en el almacén: 246
#
# Current_date: 2020-04-03 00:00:00
#
# Total de ítems en el almacén: 245
# Total de ítems en el almacén: 244
# Total de ítems en el almacén: 243
# Total de ítems en el almacén: 242
# Total de ítems en el almacén: 241
# Total de ítems en el almacén: 240
# Total de ítems en el almacén: 239
# Total de ítems en el almacén: 238
# Total de ítems en el almacén: 237
# Total de ítems en el almacén: 236
# Total de ítems en el almacén: 235
# Total de ítems en el almacén: 234
# Total de ítems en el almacén: 232
# Total de ítems en el almacén: 231
# Total de ítems en el almacén: 229
# Total de ítems en el almacén: 227
#
# Current_date: 2020-04-04 00:00:00
#
# Total de ítems en el almacén: 225
# Total de ítems en el almacén: 224
# Total de ítems en el almacén: 223
# Total de ítems en el almacén: 222
# Total de ítems en el almacén: 221
# Total de ítems en el almacén: 220
# Total de ítems en el almacén: 219
# Total de ítems en el almacén: 218
# Total de ítems en el almacén: 217
# Total de ítems en el almacén: 216
# Total de ítems en el almacén: 215
# Total de ítems en el almacén: 214
# Total de ítems en el almacén: 213
# Total de ítems en el almacén: 212
#
# Current_date: 2020-04-05 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 423
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 421
#
# Current_date: 2020-04-06 00:00:00
#
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 417
# Total de ítems en el almacén: 416
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
#
# Current_date: 2020-04-07 00:00:00
#
# Total de ítems en el almacén: 410
# Total de ítems en el almacén: 409
# Total de ítems en el almacén: 408
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 405
#
# Current_date: 2020-04-08 00:00:00
#
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 398
#
# Current_date: 2020-04-09 00:00:00
#
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
# Total de ítems en el almacén: 394
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 392
#
# Current_date: 2020-04-10 00:00:00
#
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 381
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
#
# Current_date: 2020-04-11 00:00:00
#
# Total de ítems en el almacén: 373
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
#
# Current_date: 2020-04-12 00:00:00
#
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 353
# Total de ítems en el almacén: 352
# Total de ítems en el almacén: 351
#
# Current_date: 2020-04-13 00:00:00
#
# Total de ítems en el almacén: 350
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
#
# Current_date: 2020-04-14 00:00:00
#
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 338
#
# Current_date: 2020-04-15 00:00:00
#
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 334
# Total de ítems en el almacén: 333
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
# Total de ítems en el almacén: 330
#
# Current_date: 2020-04-16 00:00:00
#
# Total de ítems en el almacén: 329
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 326
# Total de ítems en el almacén: 325
#
# Current_date: 2020-04-17 00:00:00
#
# Total de ítems en el almacén: 323
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 321
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 317
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
#
# Current_date: 2020-04-18 00:00:00
#
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 303
# Total de ítems en el almacén: 302
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 299
# Total de ítems en el almacén: 298
# Total de ítems en el almacén: 297
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 294
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 291
# Total de ítems en el almacén: 290
# Total de ítems en el almacén: 289
#
# Current_date: 2020-04-19 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 421
#
# Current_date: 2020-04-20 00:00:00
#
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 417
#
# Current_date: 2020-04-21 00:00:00
#
# Total de ítems en el almacén: 416
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
#
# Current_date: 2020-04-22 00:00:00
#
# Total de ítems en el almacén: 409
# Total de ítems en el almacén: 408
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 405
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
#
# Current_date: 2020-04-23 00:00:00
#
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 400
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 397
#
# Current_date: 2020-04-24 00:00:00
#
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
# Total de ítems en el almacén: 394
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 392
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 388
# Total de ítems en el almacén: 387
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 385
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
#
# Current_date: 2020-04-25 00:00:00
#
# Total de ítems en el almacén: 381
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 376
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
# Total de ítems en el almacén: 373
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
# Total de ítems en el almacén: 358
#
# Current_date: 2020-04-26 00:00:00
#
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 353
#
# Current_date: 2020-04-27 00:00:00
#
# Total de ítems en el almacén: 352
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
#
# Current_date: 2020-04-28 00:00:00
#
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
#
# Current_date: 2020-04-29 00:00:00
#
# Total de ítems en el almacén: 338
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 334
#
# Current_date: 2020-04-30 00:00:00
#
# Total de ítems en el almacén: 333
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
# Total de ítems en el almacén: 330
# Total de ítems en el almacén: 329
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
# Total de ítems en el almacén: 325
#
# Current_date: 2020-05-01 00:00:00
#
# Total de ítems en el almacén: 324
# Total de ítems en el almacén: 323
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 321
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 313
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 303
# ...
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 321
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 317
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 313
#
# Current_date: 2024-11-30 00:00:00
#
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 303
# Total de ítems en el almacén: 302
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 299
# Total de ítems en el almacén: 298
# Total de ítems en el almacén: 297
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 294
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 290
#
# Current_date: 2024-12-01 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 424
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 421
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 417
# Total de ítems en el almacén: 416
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
#
# Current_date: 2024-12-02 00:00:00
#
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 409
# Total de ítems en el almacén: 408
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 405
# Total de ítems en el almacén: 404
# Total de ítems en el almacén: 403
#
# Current_date: 2024-12-03 00:00:00
#
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 398
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
#
# Current_date: 2024-12-04 00:00:00
#
# Total de ítems en el almacén: 394
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 388
# Total de ítems en el almacén: 386
# Total de ítems en el almacén: 385
# Total de ítems en el almacén: 384
#
# Current_date: 2024-12-05 00:00:00
#
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 381
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 375
#
# Current_date: 2024-12-06 00:00:00
#
# Total de ítems en el almacén: 374
# Total de ítems en el almacén: 372
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 353
# Total de ítems en el almacén: 352
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 350
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 347
# Total de ítems en el almacén: 346
#
# Current_date: 2024-12-07 00:00:00
#
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
# Total de ítems en el almacén: 343
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 338
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 334
# Total de ítems en el almacén: 333
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
# Total de ítems en el almacén: 330
# Total de ítems en el almacén: 329
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
# Total de ítems en el almacén: 326
# Total de ítems en el almacén: 325
# Total de ítems en el almacén: 324
# Total de ítems en el almacén: 323
# Total de ítems en el almacén: 322
# Total de ítems en el almacén: 321
# Total de ítems en el almacén: 320
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 317
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 314
#
# Current_date: 2024-12-08 00:00:00
#
# Total de ítems en el almacén: 313
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 305
#
# Current_date: 2024-12-09 00:00:00
#
# Total de ítems en el almacén: 303
# Total de ítems en el almacén: 302
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 299
# Total de ítems en el almacén: 297
#
# Current_date: 2024-12-10 00:00:00
#
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 294
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 291
# Total de ítems en el almacén: 290
# Total de ítems en el almacén: 289
# Total de ítems en el almacén: 288
#
# Current_date: 2024-12-11 00:00:00
#
# Total de ítems en el almacén: 287
# Total de ítems en el almacén: 286
# Total de ítems en el almacén: 285
# Total de ítems en el almacén: 284
# Total de ítems en el almacén: 283
# Total de ítems en el almacén: 282
# Total de ítems en el almacén: 281
# Total de ítems en el almacén: 280
# Total de ítems en el almacén: 279
#
# Current_date: 2024-12-12 00:00:00
#
# Total de ítems en el almacén: 278
# Total de ítems en el almacén: 277
# Total de ítems en el almacén: 276
# Total de ítems en el almacén: 275
# Total de ítems en el almacén: 274
# Total de ítems en el almacén: 273
# Total de ítems en el almacén: 272
# Total de ítems en el almacén: 271
# Total de ítems en el almacén: 270
# Total de ítems en el almacén: 269
# Total de ítems en el almacén: 268
# Total de ítems en el almacén: 266
#
# Current_date: 2024-12-13 00:00:00
#
# Total de ítems en el almacén: 265
# Total de ítems en el almacén: 263
# Total de ítems en el almacén: 262
# Total de ítems en el almacén: 261
# Total de ítems en el almacén: 260
# Total de ítems en el almacén: 259
# Total de ítems en el almacén: 258
# Total de ítems en el almacén: 257
# Total de ítems en el almacén: 255
# Total de ítems en el almacén: 254
# Total de ítems en el almacén: 253
# Total de ítems en el almacén: 252
# Total de ítems en el almacén: 251
# Total de ítems en el almacén: 249
# Total de ítems en el almacén: 248
# Total de ítems en el almacén: 247
# Total de ítems en el almacén: 246
# Total de ítems en el almacén: 245
# Total de ítems en el almacén: 244
# Total de ítems en el almacén: 243
# Total de ítems en el almacén: 242
# Total de ítems en el almacén: 241
# Total de ítems en el almacén: 240
# Total de ítems en el almacén: 239
# Total de ítems en el almacén: 238
# Total de ítems en el almacén: 236
# Total de ítems en el almacén: 235
# Total de ítems en el almacén: 233
#
# Current_date: 2024-12-14 00:00:00
#
# Total de ítems en el almacén: 232
# Total de ítems en el almacén: 230
# Total de ítems en el almacén: 228
# Total de ítems en el almacén: 227
# Total de ítems en el almacén: 225
# Total de ítems en el almacén: 224
# Total de ítems en el almacén: 223
# Total de ítems en el almacén: 222
# Total de ítems en el almacén: 221
# Total de ítems en el almacén: 220
# Total de ítems en el almacén: 219
# Total de ítems en el almacén: 217
# Total de ítems en el almacén: 216
# Total de ítems en el almacén: 215
# Total de ítems en el almacén: 214
# Total de ítems en el almacén: 213
# Total de ítems en el almacén: 211
# Total de ítems en el almacén: 210
# Total de ítems en el almacén: 208
# Total de ítems en el almacén: 207
# Total de ítems en el almacén: 206
#
# Current_date: 2024-12-15 00:00:00
#
# RESTORIIIIINGGG!!!
# Total de ítems en el almacén: 427
# Total de ítems en el almacén: 426
# Total de ítems en el almacén: 425
# Total de ítems en el almacén: 423
# Total de ítems en el almacén: 422
# Total de ítems en el almacén: 421
# Total de ítems en el almacén: 420
# Total de ítems en el almacén: 419
# Total de ítems en el almacén: 418
# Total de ítems en el almacén: 417
# Total de ítems en el almacén: 416
#
# Current_date: 2024-12-16 00:00:00
#
# Total de ítems en el almacén: 415
# Total de ítems en el almacén: 414
# Total de ítems en el almacén: 413
# Total de ítems en el almacén: 412
# Total de ítems en el almacén: 411
# Total de ítems en el almacén: 410
# Total de ítems en el almacén: 409
# Total de ítems en el almacén: 408
# Total de ítems en el almacén: 407
# Total de ítems en el almacén: 406
# Total de ítems en el almacén: 405
# Total de ítems en el almacén: 404
#
# Current_date: 2024-12-17 00:00:00
#
# Total de ítems en el almacén: 403
# Total de ítems en el almacén: 402
# Total de ítems en el almacén: 401
# Total de ítems en el almacén: 400
# Total de ítems en el almacén: 399
# Total de ítems en el almacén: 397
# Total de ítems en el almacén: 396
# Total de ítems en el almacén: 395
#
# Current_date: 2024-12-18 00:00:00
#
# Total de ítems en el almacén: 394
# Total de ítems en el almacén: 393
# Total de ítems en el almacén: 392
# Total de ítems en el almacén: 391
# Total de ítems en el almacén: 390
# Total de ítems en el almacén: 389
# Total de ítems en el almacén: 387
#
# Current_date: 2024-12-19 00:00:00
#
# Total de ítems en el almacén: 385
# Total de ítems en el almacén: 384
# Total de ítems en el almacén: 383
# Total de ítems en el almacén: 382
# Total de ítems en el almacén: 381
# Total de ítems en el almacén: 380
# Total de ítems en el almacén: 379
#
# Current_date: 2024-12-20 00:00:00
#
# Total de ítems en el almacén: 378
# Total de ítems en el almacén: 377
# Total de ítems en el almacén: 376
# Total de ítems en el almacén: 375
# Total de ítems en el almacén: 374
# Total de ítems en el almacén: 373
# Total de ítems en el almacén: 371
# Total de ítems en el almacén: 370
# Total de ítems en el almacén: 369
# Total de ítems en el almacén: 368
# Total de ítems en el almacén: 367
# Total de ítems en el almacén: 366
# Total de ítems en el almacén: 365
# Total de ítems en el almacén: 364
# Total de ítems en el almacén: 363
# Total de ítems en el almacén: 362
# Total de ítems en el almacén: 361
# Total de ítems en el almacén: 360
# Total de ítems en el almacén: 359
# Total de ítems en el almacén: 358
# Total de ítems en el almacén: 357
# Total de ítems en el almacén: 356
# Total de ítems en el almacén: 355
# Total de ítems en el almacén: 354
# Total de ítems en el almacén: 353
# Total de ítems en el almacén: 352
# Total de ítems en el almacén: 351
# Total de ítems en el almacén: 349
# Total de ítems en el almacén: 348
# Total de ítems en el almacén: 346
# Total de ítems en el almacén: 345
# Total de ítems en el almacén: 344
# Total de ítems en el almacén: 343
#
# Current_date: 2024-12-21 00:00:00
#
# Total de ítems en el almacén: 342
# Total de ítems en el almacén: 341
# Total de ítems en el almacén: 340
# Total de ítems en el almacén: 339
# Total de ítems en el almacén: 338
# Total de ítems en el almacén: 337
# Total de ítems en el almacén: 336
# Total de ítems en el almacén: 335
# Total de ítems en el almacén: 334
# Total de ítems en el almacén: 333
# Total de ítems en el almacén: 332
# Total de ítems en el almacén: 331
# Total de ítems en el almacén: 330
# Total de ítems en el almacén: 329
# Total de ítems en el almacén: 328
# Total de ítems en el almacén: 327
# Total de ítems en el almacén: 325
#
# Current_date: 2024-12-22 00:00:00
#
# Total de ítems en el almacén: 323
# Total de ítems en el almacén: 321
# Total de ítems en el almacén: 319
# Total de ítems en el almacén: 318
# Total de ítems en el almacén: 317
# Total de ítems en el almacén: 316
# Total de ítems en el almacén: 315
# Total de ítems en el almacén: 314
# Total de ítems en el almacén: 313
#
# Current_date: 2024-12-23 00:00:00
#
# Total de ítems en el almacén: 312
# Total de ítems en el almacén: 311
# Total de ítems en el almacén: 310
# Total de ítems en el almacén: 309
# Total de ítems en el almacén: 308
# Total de ítems en el almacén: 307
#
# Current_date: 2024-12-24 00:00:00
#
# Total de ítems en el almacén: 306
# Total de ítems en el almacén: 305
# Total de ítems en el almacén: 304
# Total de ítems en el almacén: 303
# Total de ítems en el almacén: 302
# Total de ítems en el almacén: 301
# Total de ítems en el almacén: 300
# Total de ítems en el almacén: 299
#
# Current_date: 2024-12-25 00:00:00
#
# Total de ítems en el almacén: 297
# Total de ítems en el almacén: 296
# Total de ítems en el almacén: 295
# Total de ítems en el almacén: 294
# Total de ítems en el almacén: 293
# Total de ítems en el almacén: 292
# Total de ítems en el almacén: 291
#
# Current_date: 2024-12-26 00:00:00
#
# Total de ítems en el almacén: 290
# Total de ítems en el almacén: 289
# Total de ítems en el almacén: 288
# Total de ítems en el almacén: 287
# Total de ítems en el almacén: 286
# Total de ítems en el almacén: 285
# Total de ítems en el almacén: 284
# Total de ítems en el almacén: 283
# Total de ítems en el almacén: 282
# Total de ítems en el almacén: 281
# Total de ítems en el almacén: 280
#
# Current_date: 2024-12-27 00:00:00
#
# Total de ítems en el almacén: 279
# Total de ítems en el almacén: 278
# Total de ítems en el almacén: 277
# Total de ítems en el almacén: 275
# Total de ítems en el almacén: 274
# Total de ítems en el almacén: 273
# Total de ítems en el almacén: 272
# Total de ítems en el almacén: 271
# Total de ítems en el almacén: 270
# Total de ítems en el almacén: 269
# Total de ítems en el almacén: 268
# Total de ítems en el almacén: 267
# Total de ítems en el almacén: 265
# Total de ítems en el almacén: 264
# Total de ítems en el almacén: 263
# Total de ítems en el almacén: 262
# Total de ítems en el almacén: 260
# Total de ítems en el almacén: 259
# Total de ítems en el almacén: 258
# Total de ítems en el almacén: 257
# Total de ítems en el almacén: 256
# Total de ítems en el almacén: 255
# Total de ítems en el almacén: 254
# Total de ítems en el almacén: 253
# Total de ítems en el almacén: 252
# Total de ítems en el almacén: 251
# Total de ítems en el almacén: 249
# Total de ítems en el almacén: 248
# Total de ítems en el almacén: 247
# Total de ítems en el almacén: 246
# Total de ítems en el almacén: 245
# Total de ítems en el almacén: 244
#
# Current_date: 2024-12-28 00:00:00
#
# Total de ítems en el almacén: 243
# Total de ítems en el almacén: 242
# Total de ítems en el almacén: 241
# Total de ítems en el almacén: 240
# Total de ítems en el almacén: 239
# Total de ítems en el almacén: 238
# Total de ítems en el almacén: 237
# Total de ítems en el almacén: 236
# Total de ítems en el almacén: 235
# Total de ítems en el almacén: 234
# Total de ítems en el almacén: 233
# Total de ítems en el almacén: 232
# Total de ítems en el almacén: 230
# Total de ítems en el almacén: 229
# Total de ítems en el almacén: 228
# Total de ítems en el almacén: 227
# Total de ítems en el almacén: 226
# Total de ítems en el almacén: 224
# Total de ítems en el almacén: 223
# Total de ítems en el almacén: 222
# Total de ítems en el almacén: 221
# Total de ítems en el almacén: 220
# Total de ítems en el almacén: 219
# Total de ítems en el almacén: 217
#
# Current_date: 2024-12-29 00:00:00
#
# Total de ítems en el almacén: 216
# Total de ítems en el almacén: 215
# Total de ítems en el almacén: 214
# Total de ítems en el almacén: 213
# Total de ítems en el almacén: 212
# Total de ítems en el almacén: 211
#
# Current_date: 2024-12-30 00:00:00
#
# Total de ítems en el almacén: 210
# Total de ítems en el almacén: 209
# Total de ítems en el almacén: 208
# Total de ítems en el almacén: 207
# Total de ítems en el almacén: 206
# Total de ítems en el almacén: 205
# Total de ítems en el almacén: 204
# Total de ítems en el almacén: 203
#
# Current_date: 2024-12-31 00:00:00

# %%
# Re-importing necessary libraries and reloading data since the code environment has been reset
import matplotlib.pyplot as plt
import pandas as pd

# Cargar datos de ventas generados
sales_df = pd.read_csv('./sales_test.csv')

# Convertir la columna 'date' a formato datetime
sales_df['date'] = pd.to_datetime(sales_df['date'])

# Agrupar las ventas por día
daily_sales = sales_df.groupby('date')['quantity'].sum().reset_index()

# Graficar ventas vs días del año
plt.figure(figsize=(14, 7))
plt.plot(daily_sales['date'], daily_sales['quantity'], marker='o', linestyle='-', color='skyblue', label='Ventas Diarias')
plt.title('Ventas Diarias Durante Todo el Año', fontsize=16)
plt.xlabel('Fecha', fontsize=14)
plt.ylabel('Cantidad Vendida', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Asegurarnos de que la columna 'date' sea de tipo datetime
sales_df['date'] = pd.to_datetime(sales_df['date'])

# Calcular las ventas mensuales
monthly_sales = sales_df.groupby(sales_df['date'].dt.to_period('M'))['quantity'].sum()

# Crear la gráfica
plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='bar')
plt.title('Volumen de Ventas Mensuales')
plt.xlabel('Mes')
plt.ylabel('Cantidad Vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
sales_data = pd.read_csv('sales_test.csv')
sales_data['date'] = pd.to_datetime(sales_data['date'])  # Convertir la fecha a formato datetime

# Filtrar por un producto específico
product_id_to_analyze = 1  # Cambia este ID al del producto que deseas analizar
product_sales = sales_data[sales_data['product_id'] == product_id_to_analyze]

# Agregar columna de mes y día
product_sales['month'] = product_sales['date'].dt.month
product_sales['day'] = product_sales['date'].dt.day

# Crear una figura con subplots para cada mes
fig, axes = plt.subplots(3, 4, figsize=(20, 15), sharey=True)
fig.suptitle(f'Frecuencia de Venta del Producto {product_id_to_analyze} por Día del Mes', fontsize=16)

# Generar un gráfico para cada mes
for month in range(1, 13):
    ax = axes[(month-1)//4, (month-1)%4]
    month_data = product_sales[product_sales['month'] == month]
    daily_sales = month_data.groupby('day')['quantity'].sum().reset_index()
    
    ax.bar(daily_sales['day'], daily_sales['quantity'], color='skyblue', edgecolor='black')
    ax.set_title(f'Mes {month}')
    ax.set_xlabel('Día del Mes')
    ax.set_ylabel('Cantidad Vendida')
    ax.set_xticks(range(1, 32))  # Mostrar días del 1 al 31
    ax.grid(axis='y', linestyle='--', alpha=0.7)

# Ajustar el espacio entre subplots
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# /tmp/ipykernel_11833/3250654184.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_sales['month'] = product_sales['date'].dt.month
# /tmp/ipykernel_11833/3250654184.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_sales['day'] = product_sales['date'].dt.day

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Asegurarte de que la columna 'date' sea de tipo datetime
sales_df['date'] = pd.to_datetime(sales_df['date'])

# Crear una columna con el día de la semana (lunes=0, ..., domingo=6)
sales_df['weekday'] = sales_df['date'].dt.weekday

# Agrupar por día de la semana y sumar las ventas
sales_by_weekday = sales_df.groupby('weekday')['quantity'].sum()

# Cambiar los índices a nombres de los días
sales_by_weekday.index = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']

# Crear el gráfico
plt.figure(figsize=(10, 6))
sales_by_weekday.plot(kind='bar', color='skyblue')
plt.title('Ventas Anuales por Día de la Semana')
plt.xlabel('Día de la Semana')
plt.ylabel('Cantidad Total Vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
sales_data = pd.read_csv('sales_test.csv')
sales_data['date'] = pd.to_datetime(sales_data['date'])  # Convertir la fecha a formato datetime

# Agregar columnas para mes y día de la semana
sales_data['month'] = sales_data['date'].dt.month
sales_data['day_of_week'] = sales_data['date'].dt.day_name()

# Crear un DataFrame con las ventas promedio por día de la semana para cada mes
monthly_weekday_sales = sales_data.groupby(['month', 'day_of_week'])['quantity'].sum().reset_index()

# Ordenar los días de la semana en el orden correcto
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
monthly_weekday_sales['day_of_week'] = pd.Categorical(
    monthly_weekday_sales['day_of_week'], 
    categories=days_order, 
    ordered=True
)

# Ordenar los datos por mes y día de la semana
monthly_weekday_sales = monthly_weekday_sales.sort_values(['month', 'day_of_week'])

# Crear una figura con subplots para cada mes
fig, axes = plt.subplots(3, 4, figsize=(20, 15), sharey=True)
fig.suptitle('Ventas Promedio por Día de la Semana en Cada Mes', fontsize=16)

# Generar un gráfico para cada mes
for month in range(1, 13):
    ax = axes[(month-1)//4, (month-1)%4]
    month_data = monthly_weekday_sales[monthly_weekday_sales['month'] == month]
    ax.bar(month_data['day_of_week'], month_data['quantity'], color='skyblue')
    ax.set_title(f'Mes {month}')
    ax.set_xlabel('Día de la Semana')
    ax.set_ylabel('Ventas Promedio')
    ax.grid(axis='y')

# Ajustar el espacio entre subplots
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt

# Asegurarnos de que las columnas de fechas sean de tipo datetime
sales_df['date'] = pd.to_datetime(sales_df['date'])
sales_df['batch_expiry_date'] = pd.to_datetime(sales_df['batch_expiry_date'])

# Calcular los días restantes para la caducidad
sales_df['days_to_expiry'] = (sales_df['batch_expiry_date'] - sales_df['date']).dt.days

# Agrupar por días restantes y sumar las ventas
sales_by_expiry = sales_df.groupby('days_to_expiry')['quantity'].sum()

# Crear el gráfico
plt.figure(figsize=(10, 6))
sales_by_expiry.plot(kind='bar', color='skyblue', width=1)
plt.title('Volumen de Ventas por Días Restantes para Caducar')
plt.xlabel('Días Restantes para Caducar')
plt.ylabel('Cantidad Vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
unsold_products_list = [
    {'product_id': product_id, 'quantity': batch['quantity'], 'expiry_date': batch['expiry_date']}
    for product_id, batches in unsold_products.items()
    for batch in batches
]

print(unsold_products_list)
# Out:
# []
